# %% [markdown]
# ### Description
#     Problem: Evil Numbers
#     Link: https://code.golf/evil-numbers#python
#     Solution characters: 46

# %%
for i in range(51):i.bit_count()&1 or print(i)
# Out:
# 0
# 3
# 5
# 6
# 9
# 10
# 12
# 15
# 17
# 18
# 20
# 23
# 24
# 27
# 29
# 30
# 33
# 34
# 36
# 39
# 40
# 43
# 45
# 46
# 48
