# %% [markdown]
# ### Description
#     Problem: Foo Fizz Buzz Bar
#     Link: https://code.golf/foo-fizz-buzz-bar#python
#     Solution characters: 99

# %%
for v in range(1,1001):print('Foo'*(not v%2)+'Fizz'*(not v%3)+'Buzz'*(not v%5)+'Bar'*(not v%7)or v)
# Out:
# 1
# Foo
# Fizz
# Foo
# Buzz
# FooFizz
# Bar
# Foo
# Fizz
# FooBuzz
# 11
# FooFizz
# 13
# FooBar
# FizzBuzz
# Foo
# 17
# FooFizz
# 19
# FooBuzz
# FizzBar
# Foo
# 23
# FooFizz
# Buzz
# Foo
# Fizz
# FooBar
# 29
# FooFizzBuzz
# 31
# Foo
# Fizz
# Foo
# BuzzBar
# FooFizz
# 37
# Foo
# Fizz
# FooBuzz
# 41
# FooFizzBar
# 43
# Foo
# FizzBuzz
# Foo
# 47
# FooFizz
# Bar
# FooBuzz
# Fizz
# Foo
# 53
# FooFizz
# Buzz
# FooBar
# Fizz
# Foo
# 59
# FooFizzBuzz
# 61
# Foo
# FizzBar
# Foo
# Buzz
# FooFizz
# 67
# Foo
# Fizz
# FooBuzzBar
# 71
# FooFizz
# 73
# Foo
# FizzBuzz
# Foo
# Bar
# FooFizz
# 79
# FooBuzz
# Fizz
# Foo
# 83
# FooFizzBar
# Buzz
# Foo
# Fizz
# Foo
# 89
# FooFizzBuzz
# Bar
# Foo
# Fizz
# Foo
# Buzz
# FooFizz
# 97
# FooBar
# Fizz
# FooBuzz
# 101
# FooFizz
# 103
# Foo
# FizzBuzzBar
# Foo
# 107
# FooFizz
# 109
# FooBuzz
# Fizz
# FooBar
# 113
# FooFizz
# Buzz
# Foo
# Fizz
# Foo
# Bar
# FooFizzBuzz
# 121
# Foo
# Fizz
# Foo
# Buzz
# FooFizzBar
# 127
# Foo
# Fizz
# FooBuzz
# 131
# FooFizz
# ...
