# %% [markdown]
# ### Description
#     Problem: Rule 110
#     Link: https://code.golf/rule-110#python
#     Solution characters: 164

# %% [markdown]
# ### Variables used
#     u = universe of values
#     n = new row in the universe
#     w = width of the window
#     d = display the row
#     f = apply the Rule 110 algorithm

# %%
r=range
u={-1}
for i in r(100):
    print(''.join([' ','█'][x in u]for x in r(-100,0)));n=set()
    for x in u:x+1 not in u==n.add(x);x-1 not in u==n.update([x,x-1])
    u=n
# Out:
#                                                                                                    █
#                                                                                                   ██
#                                                                                                  ███
#                                                                                                 ██ █
#                                                                                                █████
#                                                                                               ██   █
#                                                                                              ███  ██
#                                                                                             ██ █ ███
#                                                                                            ███████ █
# ...
