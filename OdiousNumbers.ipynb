# %% [markdown]
# ### Description
#     Problem: Odious Numbers
#     Link: https://code.golf/odious-numbers#python
#     Solution characters: 46

# %%
for i in range(51):i.bit_count()%2and print(i)
# Out:
# 1
# 2
# 4
# 7
# 8
# 11
# 13
# 14
# 16
# 19
# 21
# 22
# 25
# 26
# 28
# 31
# 32
# 35
# 37
# 38
# 41
# 42
# 44
# 47
# 49
# 50
